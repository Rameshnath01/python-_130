# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB 487.6 kB/s eta 0:00:30
#    ---------------------------------------- 0.1/14.5 MB 465.5 kB/s eta 0:00:31
#    ---------------------------------------- 0.1/14.5 MB 476.3 kB/s eta 0:00:31
#    ---------------------------------------- 0.1/14.5 MB 504.4 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/14.5 MB 532.5 kB/s eta 0:00:27
#    ---------------------------------------- 0.2/14.5 MB 551.6 kB/s eta 0:00:26
#     --------------------------------------- 0.2/14.5 MB 535.8 kB/s eta 0:00:27
#     --------------------------------------- 0.2/14.5 MB 518.8 kB/s eta 0:00:28
#     --------------------------------------- 0.3/14.5 MB 524.0 kB/s eta 0:00:28
#     --------------------------------------- 0.3/14.5 MB 535.8 kB/s eta 0:00:27
# ...

# %%
import mysql.connector                  #importing database
database = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "",
    database = "python_class_1:30")

db = database.cursor()

# %%
sql ='''INSERT INTO `student` (`id`, `name`, `math`, `physics`, `chemistry`, `english`, `nepali`, `per`, `garade`, `total`) VALUES ('5', 'Ram', '35', '33', '5', '326', '655', '77', 'F', '777');'''

db.execute(sql)
database.commit()

# %%
n = int(input("Enter n = "))
for i in range(1,n+1):
    name = input("Enter name = ")
    physics = int(input("Enter physics marks = "))
    chemistry = int(input("Enter chemistry marks ="))
    math = int(input("Enter math marks = "))
    english = int(input("Enter english marks ="))
    nepali = int(input("Enter nepali marks ="))
    
    total = physics+chemistry+math+english+nepali
    per = total/5
    if per>=80:
        grade = 'A'

    elif per>=60:
        grade = 'B'

    elif per>=45:
        grade = 'C'
    elif per>=32:
        grade = 'D'
    else:
        grade = 'F'
        
    sql = f'''  INSERT INTO student( name, physics, chemistry, math, english, nepali, total, per, grade) 
      VALUES('{name}', {physics}, {chemistry}, {math}, {english}, {nepali}, {total},{ per}, '{grade}')'''
    db.execute(sql)

database.commit()
# Out:
# Enter n =  1
# Enter name =  Ram
# Enter physics marks =  29
# Enter chemistry marks = 28
# Enter math marks =  449
# Enter english marks = 23
# Enter nepali marks = 43

# %%
# update
sql = '''update student SET per = 82.6 WHERE sn = 1'''
db.execute(sql)
database.commit()

# %%
# delete
sql = "DELETE FROM student WHERE `student`.`sn` = 2"
db.execute(sql)
database.commit()
